# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/299-code/blob/main/danl_299_script_2025_1002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")

# %%
emp
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male     8/6/93       NaN   True     Marketing
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
emp["First Name"] == "Donna"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: First Name, Length: 1001, dtype: bool

# %%
emp[["First Name"]] == "Donna"
# Out:
#       First Name
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 996        False
# 997        False
# 998        False
# 999        False
# 1000       False
#
# [1001 rows x 1 columns]

# %%
emp[ emp["First Name"] == "Donna" ]
# Out:
#     First Name  Gender Start Date   Salary   Mgmt       Team
# 19       Donna  Female    7/22/10  81014.0  False    Product
# 88       Donna  Female   11/27/91  64088.0   True      Legal
# 986      Donna  Female   11/26/82  82871.0  False  Marketing

# %%
donnas = emp["First Name"] == "Donna"
emp[ donnas ]
# Out:
#     First Name  Gender Start Date   Salary   Mgmt       Team
# 19       Donna  Female    7/22/10  81014.0  False    Product
# 88       Donna  Female   11/27/91  64088.0   True      Legal
# 986      Donna  Female   11/26/82  82871.0  False  Marketing

# %%
non_marketing = emp['Team'] != "Marketing"
emp[non_marketing]
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# 5        Dennis    Male    4/18/87  115163.0  False         Legal
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN    NaN           NaN
#
# [903 rows x 6 columns]

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.1+ KB

# %%
emp[ emp['Mgmt'] ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-161339784.py in <cell line: 0>()
# ----> 1 emp[ emp['Mgmt'] ]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
(
 emp['Mgmt'].isna()
)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000     True
# Name: Mgmt, Length: 1001, dtype: bool

# %%
(
 emp
 .astype(
     {'Mgmt':'bool'}
 )
)
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male     8/6/93       NaN   True     Marketing
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN   True           NaN
#
# [1001 rows x 6 columns]

# %%
emp_nonNA_on_Mgmt = (
 emp[ emp['Mgmt'].notna() ]
 .astype(
     {'Mgmt':'bool'}
 )
)

# %%
emp_nonNA_on_Mgmt
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male     8/6/93       NaN   True     Marketing
# 1       Thomas    Male    3/31/96   61933.0   True           NaN
# 2        Maria  Female        NaN  130590.0  False       Finance
# 3        Jerry     NaN     3/4/05  138705.0   True       Finance
# 4        Larry    Male    1/24/98  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN   11/23/14  132483.0  False  Distribution
# 996    Phillip    Male    1/31/84   42392.0  False       Finance
# 997    Russell    Male    5/20/13   96914.0  False       Product
# 998      Larry    Male    4/20/13   60500.0  False  Business Dev
# 999     Albert    Male    5/15/12  129949.0   True         Sales
#
# [933 rows x 6 columns]

# %%
emp_nonNA_on_Mgmt[ emp_nonNA_on_Mgmt['Mgmt'] ]
# Out:
#     First Name  Gender Start Date    Salary  Mgmt         Team
# 0      Douglas    Male     8/6/93       NaN  True    Marketing
# 1       Thomas    Male    3/31/96   61933.0  True          NaN
# 3        Jerry     NaN     3/4/05  138705.0  True      Finance
# 4        Larry    Male    1/24/98  101004.0  True           IT
# 6         Ruby  Female    8/17/87   65476.0  True      Product
# ..         ...     ...        ...       ...   ...          ...
# 991       Rose  Female    8/25/02  134505.0  True    Marketing
# 992    Anthony    Male   10/16/11  112769.0  True      Finance
# 993       Tina  Female    5/15/97   56450.0  True  Engineering
# 994     George    Male    6/21/13   98874.0  True    Marketing
# 999     Albert    Male    5/15/12  129949.0  True        Sales
#
# [468 rows x 6 columns]

# %%
emp_nonNA_on_Mgmt[ emp_nonNA_on_Mgmt['Mgmt'] == True ]
# Out:
#     First Name  Gender Start Date    Salary  Mgmt         Team
# 0      Douglas    Male     8/6/93       NaN  True    Marketing
# 1       Thomas    Male    3/31/96   61933.0  True          NaN
# 3        Jerry     NaN     3/4/05  138705.0  True      Finance
# 4        Larry    Male    1/24/98  101004.0  True           IT
# 6         Ruby  Female    8/17/87   65476.0  True      Product
# ..         ...     ...        ...       ...   ...          ...
# 991       Rose  Female    8/25/02  134505.0  True    Marketing
# 992    Anthony    Male   10/16/11  112769.0  True      Finance
# 993       Tina  Female    5/15/97   56450.0  True  Engineering
# 994     George    Male    6/21/13   98874.0  True    Marketing
# 999     Albert    Male    5/15/12  129949.0  True        Sales
#
# [468 rows x 6 columns]

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.1+ KB

# %%
high_earners = emp["Salary"] > 100000
emp[ high_earners ]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 2        Maria  Female        NaN  130590.0  False       Finance
# 3        Jerry     NaN     3/4/05  138705.0   True       Finance
# 4        Larry    Male    1/24/98  101004.0   True            IT
# 5       Dennis    Male    4/18/87  115163.0  False         Legal
# 9      Frances  Female     8/8/02  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 990      Robin  Female    7/24/87  100765.0   True            IT
# 991       Rose  Female    8/25/02  134505.0   True     Marketing
# 992    Anthony    Male   10/16/11  112769.0   True       Finance
# 995      Henry     NaN   11/23/14  132483.0  False  Distribution
# 999     Albert    Male    5/15/12  129949.0   True         Sales
#
# [409 rows x 6 columns]

# %%
emp['Team'].value_counts()
# Out:
# Team
# IT              106
# Finance         102
# Business Dev    101
# Marketing        98
# Product          95
# Sales            94
# Engineering      92
# HR               91
# Distribution     90
# Legal            88
# Name: count, dtype: int64

# %%
sales = emp['Team'] == 'Sales'
legal = emp['Team'] == 'Legal'
finance = emp['Team'] == 'Finance'

emp[ sales | legal | finance ]['Team'].unique()
# Out:
# array(['Finance', 'Legal', 'Sales'], dtype=object)

# %%
sales = emp["Team"] == "Sales"
legal = emp["Team"] == "Legal"
fnce = emp["Team"] == "Finance"
emp[ sales | legal | fnce ] # '|' is 'or' opeartor
# Out:
#     First Name  Gender Start Date    Salary   Mgmt     Team
# 2        Maria  Female        NaN  130590.0  False  Finance
# 3        Jerry     NaN     3/4/05  138705.0   True  Finance
# 5       Dennis    Male    4/18/87  115163.0  False    Legal
# 7          NaN  Female    7/20/15   45906.0    NaN  Finance
# 11       Julie  Female   10/26/97  102508.0   True    Legal
# ..         ...     ...        ...       ...    ...      ...
# 987     Gloria  Female    12/8/14  136709.0   True  Finance
# 989     Justin     NaN    2/10/91   38344.0  False    Legal
# 992    Anthony    Male   10/16/11  112769.0   True  Finance
# 996    Phillip    Male    1/31/84   42392.0  False  Finance
# 999     Albert    Male    5/15/12  129949.0   True    Sales
#
# [284 rows x 6 columns]

# %%
emp[ emp["Team"] == "Sales" | emp["Team"] == "Legal" ] # '|' is 'or' opeartor
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     361         #  (xint or xbool) and (yint or bool)
# --> 362         result = op(x, y)
#     363     except TypeError:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/roperator.py in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#      59
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     375             try:
# --> 376                 result = libops.scalar_binop(x, y, op)
#     377             except (
#
# ...

# %%
emp[ ( emp["Team"] == "Sales" ) | ( emp["Team"] == "Legal" ) ]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt   Team
# 5       Dennis    Male    4/18/87  115163.0  False  Legal
# 11       Julie  Female   10/26/97  102508.0   True  Legal
# 13        Gary    Male    1/27/08  109831.0  False  Sales
# 20        Lois     NaN    4/22/95   64714.0   True  Legal
# 27       Scott     NaN    7/11/91  122367.0  False  Legal
# ..         ...     ...        ...       ...    ...    ...
# 976     Denise  Female   10/19/92  137954.0   True  Legal
# 981      James    Male    1/15/93  148985.0  False  Legal
# 985    Stephen     NaN    7/10/83   85668.0  False  Legal
# 989     Justin     NaN    2/10/91   38344.0  False  Legal
# 999     Albert    Male    5/15/12  129949.0   True  Sales
#
# [182 rows x 6 columns]

# %%
star_teams = ["Sales", "Legal", "Finance"]
on_star_teams = emp['Team'].isin(star_teams)
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 996      True
# 997     False
# 998     False
# 999      True
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
emp[on_star_teams]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt     Team
# 2        Maria  Female        NaN  130590.0  False  Finance
# 3        Jerry     NaN     3/4/05  138705.0   True  Finance
# 5       Dennis    Male    4/18/87  115163.0  False    Legal
# 7          NaN  Female    7/20/15   45906.0    NaN  Finance
# 11       Julie  Female   10/26/97  102508.0   True    Legal
# ..         ...     ...        ...       ...    ...      ...
# 987     Gloria  Female    12/8/14  136709.0   True  Finance
# 989     Justin     NaN    2/10/91   38344.0  False    Legal
# 992    Anthony    Male   10/16/11  112769.0   True  Finance
# 996    Phillip    Male    1/31/84   42392.0  False  Finance
# 999     Albert    Male    5/15/12  129949.0   True    Sales
#
# [284 rows x 6 columns]

# %%
emp['Team'].isin(["Sales"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999      True
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
higher_than_90k = emp["Salary"] >= 90000
lower_than_100k = emp["Salary"] < 100000
emp[ higher_than_90k & lower_than_100k ] # '&' is 'and' opeartor
# Out:
#     First Name  Gender Start Date   Salary   Mgmt         Team
# 8       Angela  Female   11/22/05  95570.0   True  Engineering
# 16      Jeremy    Male    9/21/10  90370.0  False           HR
# 22      Joshua     NaN     3/8/12  90816.0   True           IT
# 24        John    Male     7/1/92  97950.0  False           IT
# 34       Jerry    Male    1/10/04  95734.0  False           IT
# ..         ...     ...        ...      ...    ...          ...
# 966      Louis    Male    8/16/11  93022.0   True           HR
# 975      Susan  Female     4/7/95  92436.0  False        Sales
# 982       Rose  Female     4/6/82  91411.0   True           HR
# 994     George    Male    6/21/13  98874.0   True    Marketing
# 997    Russell    Male    5/20/13  96914.0  False      Product
#
# [94 rows x 6 columns]

# %%
between_90k_and_100k = emp["Salary"].between(90_000, 100_000)
between_90k_and_100k
emp[between_90k_and_100k]
# Out:
#     First Name  Gender Start Date   Salary   Mgmt         Team
# 8       Angela  Female   11/22/05  95570.0   True  Engineering
# 16      Jeremy    Male    9/21/10  90370.0  False           HR
# 22      Joshua     NaN     3/8/12  90816.0   True           IT
# 24        John    Male     7/1/92  97950.0  False           IT
# 34       Jerry    Male    1/10/04  95734.0  False           IT
# ..         ...     ...        ...      ...    ...          ...
# 966      Louis    Male    8/16/11  93022.0   True           HR
# 975      Susan  Female     4/7/95  92436.0  False        Sales
# 982       Rose  Female     4/6/82  91411.0   True           HR
# 994     George    Male    6/21/13  98874.0   True    Marketing
# 997    Russell    Male    5/20/13  96914.0  False      Product
#
# [94 rows x 6 columns]

# %%
between_90k_and_99747 = emp["Salary"].between(90_000, 99747)
between_90k_and_99747
emp[between_90k_and_99747]
# Out:
#     First Name  Gender Start Date   Salary   Mgmt         Team
# 8       Angela  Female   11/22/05  95570.0   True  Engineering
# 16      Jeremy    Male    9/21/10  90370.0  False           HR
# 22      Joshua     NaN     3/8/12  90816.0   True           IT
# 24        John    Male     7/1/92  97950.0  False           IT
# 34       Jerry    Male    1/10/04  95734.0  False           IT
# ..         ...     ...        ...      ...    ...          ...
# 966      Louis    Male    8/16/11  93022.0   True           HR
# 975      Susan  Female     4/7/95  92436.0  False        Sales
# 982       Rose  Female     4/6/82  91411.0   True           HR
# 994     George    Male    6/21/13  98874.0   True    Marketing
# 997    Russell    Male    5/20/13  96914.0  False      Product
#
# [94 rows x 6 columns]

# %%
name_starts_with_t = emp["First Name"].between("T", "U")
emp[ name_starts_with_t ]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 1       Thomas    Male    3/31/96   61933.0   True           NaN
# 28       Terry    Male   11/27/81  124008.0   True            IT
# 35     Theresa  Female   10/10/06   85182.0  False         Sales
# 52        Todd    Male    2/18/90   49339.0   True            HR
# 58     Theresa  Female    4/11/10   72670.0   True   Engineering
# 70        Todd     NaN    6/10/03   84692.0  False            IT
# 74      Thomas    Male     6/4/95   62096.0  False     Marketing
# 98        Tina  Female    6/16/16  100705.0   True     Marketing
# 113       Tina  Female    6/12/09  114767.0   True   Engineering
# 143     Teresa     NaN    1/28/16  140013.0   True   Engineering
# 163      Terry    Male     9/3/90   52226.0  False            IT
# 227       Todd    Male    4/13/99   59728.0   True            IT
# 270     Thomas    Male     4/6/11  103235.0   True            HR
# ...

# %%
emp.query("Salary >= 100000 & Team == 'Finance'")
# Out:
#     First Name  Gender Start Date    Salary   Mgmt     Team
# 2        Maria  Female        NaN  130590.0  False  Finance
# 3        Jerry     NaN     3/4/05  138705.0   True  Finance
# 46       Bruce    Male   11/28/09  114796.0  False  Finance
# 56        Carl    Male     5/3/06  130276.0   True  Finance
# 69       Irene     NaN    7/14/15  100863.0   True  Finance
# 83       Shawn    Male    9/23/05  148115.0   True  Finance
# 96     Cynthia  Female    3/21/94  142321.0  False  Finance
# 103    Phyllis  Female   10/11/96  136984.0   True  Finance
# 117     Steven    Male     3/1/95  109095.0  False  Finance
# 142  Elizabeth  Female    10/9/03  146129.0  False  Finance
# 160      Kathy  Female    3/18/00  149563.0   True  Finance
# 205    Brandon    Male    3/27/06  115711.0   True  Finance
# 219      Billy    Male    3/13/95  120444.0   True  Finance
# 241     Walter    Male     7/6/83  127813.0  False  Finance
# 318        Roy    Male     8/6/06  148225.0  False  Finance
# ...

# %%
emp.query("Salary >= 100000 & `First Name` == 'Douglas'")
# Out:
#     First Name Gender Start Date    Salary   Mgmt         Team
# 667    Douglas    NaN     2/4/09  104496.0   True    Marketing
# 835    Douglas   Male     8/4/07  132175.0  False  Engineering

# %%
emp.query("Salary >= 100000 & First Name == 'Douglas'")
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipython-input-3250569886.py", line 1, in <cell line: 0>
#     emp.query("Salary >= 100000 & First Name == 'Douglas'")
#
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/frame.py", line 4823, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/frame.py", line 4949, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/computation/eval.py", line 336, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py", line 809, in __init__
#     self.terms = self.parse()
#
# ...

# %%
import numpy as np

# %%
emp['high_salary'] = np.where(emp['Salary'] >= 100_000,
                              "Yes", "No")

emp
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team high_salary
# 0       Douglas    Male     8/6/93       NaN   True     Marketing          No
# 1        Thomas    Male    3/31/96   61933.0   True           NaN          No
# 2         Maria  Female        NaN  130590.0  False       Finance         Yes
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance         Yes
# 4         Larry    Male    1/24/98  101004.0   True            IT         Yes
# ...         ...     ...        ...       ...    ...           ...         ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance          No
# 997     Russell    Male    5/20/13   96914.0  False       Product          No
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev          No
# 999      Albert    Male    5/15/12  129949.0   True         Sales         Yes
# 1000        NaN     NaN        NaN       NaN    NaN           NaN          No
#
# [1001 rows x 7 columns]

# %%
emp['high_salary'] = np.where(emp['Salary'] >= 100_000,
                              "Yes", "No")
emp['high_salary'] = np.where(emp['Salary'].isna(),
                              pd.NA, emp['high_salary']) # <NA>
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   First Name   933 non-null    object
#  1   Gender       854 non-null    object
#  2   Start Date   999 non-null    object
#  3   Salary       999 non-null    float64
#  4   Mgmt         933 non-null    object
#  5   Team         957 non-null    object
#  6   high_salary  999 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 54.9+ KB

# %%
emp['high_salary'] = np.where(emp['Salary'] >= 100_000,
                              "Yes", "No")
emp['high_salary'] = np.where(emp['Salary'].isna(),
                              np.nan, emp['high_salary'])
emp
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team high_salary
# 0       Douglas    Male     8/6/93       NaN   True     Marketing         NaN
# 1        Thomas    Male    3/31/96   61933.0   True           NaN          No
# 2         Maria  Female        NaN  130590.0  False       Finance         Yes
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance         Yes
# 4         Larry    Male    1/24/98  101004.0   True            IT         Yes
# ...         ...     ...        ...       ...    ...           ...         ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance          No
# 997     Russell    Male    5/20/13   96914.0  False       Product          No
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev          No
# 999      Albert    Male    5/15/12  129949.0   True         Sales         Yes
# 1000        NaN     NaN        NaN       NaN    NaN           NaN         NaN
#
# [1001 rows x 7 columns]

# %%
emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv", parse_dates=['Start Date'])
emp
# Out:
# /tmp/ipython-input-649200241.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv", parse_dates=['Start Date'])
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# ...

# %%
emp['Team'].isna()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
emp['Team']
# Out:
# 0          Marketing
# 1                NaN
# 2            Finance
# 3            Finance
# 4                 IT
#             ...
# 996          Finance
# 997          Product
# 998     Business Dev
# 999            Sales
# 1000             NaN
# Name: Team, Length: 1001, dtype: object

# %%
emp["Start Date"].isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000     True
# Name: Start Date, Length: 1001, dtype: bool

# %%
emp["Start Date"]
# Out:
# 0      1993-08-06
# 1      1996-03-31
# 2             NaT
# 3      2005-03-04
# 4      1998-01-24
#           ...
# 996    1984-01-31
# 997    2013-05-20
# 998    2013-04-20
# 999    2012-05-15
# 1000          NaT
# Name: Start Date, Length: 1001, dtype: datetime64[ns]

# %%
emp

# %%
# Below two are equivalent.
emp["Team"].notna()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
~emp["Team"].isna()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
emp["Team"].isna()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
# ~True
# Out:
# -2

# %%
# Q. How can we pull out employees with non-missing Team values?
emp[ ~emp['Team'].isna() ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 957 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  899 non-null    object
#  1   Gender      815 non-null    object
#  2   Start Date  956 non-null    datetime64[ns]
#  3   Salary      956 non-null    float64
#  4   Mgmt        899 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 52.3+ KB

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
emp["Mgmt"].isna().sum()
# Out:
# np.int64(68)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.1+ KB

# %%
emp["Mgmt"].value_counts()
# Out:
# Mgmt
# True     468
# False    465
# Name: count, dtype: int64

# %%
emp["Mgmt"].value_counts(dropna=False)
# Out:
# Mgmt
# True     468
# False    465
# NaN       68
# Name: count, dtype: int64

# %%
emp.dropna()
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [761 rows x 6 columns]

# %%
emp.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 761 entries, 4 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  761 non-null    object
#  1   Gender      761 non-null    object
#  2   Start Date  761 non-null    datetime64[ns]
#  3   Salary      761 non-null    float64
#  4   Mgmt        761 non-null    object
#  5   Team        761 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 41.6+ KB

# %%
emp.dropna(how = "all")
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [1000 rows x 6 columns]

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.1+ KB

# %%
emp.dropna(how = "all").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 54.7+ KB

# %%
# they are same:
emp.dropna(how = "any").info()
emp.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 761 entries, 4 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  761 non-null    object
#  1   Gender      761 non-null    object
#  2   Start Date  761 non-null    datetime64[ns]
#  3   Salary      761 non-null    float64
#  4   Mgmt        761 non-null    object
#  5   Team        761 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 41.6+ KB

# %%
emp.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 761 entries, 4 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  761 non-null    object
#  1   Gender      761 non-null    object
#  2   Start Date  761 non-null    datetime64[ns]
#  3   Salary      761 non-null    float64
#  4   Mgmt        761 non-null    object
#  5   Team        761 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 41.6+ KB

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.1+ KB

# %%
emp['Gender'].isna().sum()
# Out:
# np.int64(147)

# %%
emp.dropna(subset = ['Gender']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 854 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  794 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  853 non-null    datetime64[ns]
#  3   Salary      853 non-null    float64
#  4   Mgmt        794 non-null    object
#  5   Team        815 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 46.7+ KB

# %%
emp.dropna(subset = ["Start Date"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  932 non-null    object
#  1   Gender      853 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      998 non-null    float64
#  4   Mgmt        932 non-null    object
#  5   Team        956 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 54.6+ KB

# %%
emp.dropna(subset = ["Salary"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 1 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  932 non-null    object
#  1   Gender      853 non-null    object
#  2   Start Date  998 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        932 non-null    object
#  5   Team        956 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 54.6+ KB

# %%
emp.dropna(subset = ["Start Date", "Salary"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 998 entries, 1 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  931 non-null    object
#  1   Gender      852 non-null    object
#  2   Start Date  998 non-null    datetime64[ns]
#  3   Salary      998 non-null    float64
#  4   Mgmt        931 non-null    object
#  5   Team        955 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 54.6+ KB

# %%
emp[['Team']]
# Out:
#               Team
# 0        Marketing
# 1              NaN
# 2          Finance
# 3          Finance
# 4               IT
# ...            ...
# 996        Finance
# 997        Product
# 998   Business Dev
# 999          Sales
# 1000           NaN
#
# [1001 rows x 1 columns]

# %%
emp['Team'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
emp["Team"].duplicated(keep = "first")
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
tmp = emp["Team"].duplicated(keep = "first") == emp["Team"].duplicated()

# %%
tmp.sum()
# Out:
# np.int64(1001)

# %%
emp["Team"].duplicated(keep = "last") == emp["Team"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
~emp["Team"].duplicated()
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
emp.drop_duplicates()
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
emp.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.1+ KB

# %%
# Sample DataFrame with duplicate observations
data = {
    'Name': ['John', 'Anna', 'John', 'Mike', 'Anna'],
    'Age': [28, 23, 28, 32, 23],
    'City': ['New York', 'Paris', 'New York', 'London', 'Paris']
}

# pd.DataFrame( Series, List, or Dict ) creates a DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Anna   23     Paris
# 2  John   28  New York
# 3  Mike   32    London
# 4  Anna   23     Paris

# %%
df_unique = df.drop_duplicates()
df_unique
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Anna   23     Paris
# 3  Mike   32    London

# %%
emp.drop_duplicates(subset=['Team'])
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
emp.drop_duplicates(subset=['Team']).shape[0]
# Out:
# 11

# %%
emp.drop_duplicates(subset=["Gender", "Team"])
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# 10      Louise  Female 1980-08-12   63241.0   True           NaN
# 11       Julie  Female 1997-10-26  102508.0   True         Legal
# 12     Brandon    Male 1980-12-01  112807.0   True            HR
# 13        Gary    Male 2008-01-27  109831.0  False         Sales
# ...

# %%
(
    emp
    .drop_duplicates(subset=["Gender", "Team"])
    .sort_values(["Team", "Gender"])
)
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# 48    Clarence    Male 1996-03-26   93581.0   True  Business Dev
# 41   Christine     NaN 2015-06-28   66582.0   True  Business Dev
# 76    Margaret  Female 1988-09-10  131604.0   True  Distribution
# 40     Michael    Male 2008-10-10   99283.0   True  Distribution
# 60       Paula     NaN 2005-11-23   48866.0  False  Distribution
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 171    Patrick    Male 2007-08-17  143499.0   True   Engineering
# 143     Teresa     NaN 2016-01-28  140013.0   True   Engineering
# 2        Maria  Female        NaT  130590.0  False       Finance
# 46       Bruce    Male 2009-11-28  114796.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 75      Bonnie  Female 1991-07-02  104897.0   True            HR
# ...

# %%
emp.drop_duplicates(subset = ["Team"])
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
emp.drop_duplicates(subset = ["Team"], keep = "first")
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
emp.drop_duplicates(subset = ["Team"], keep = "last")
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 988       Alice  Female 2004-10-05   47638.0  False            HR
# 989      Justin     NaN 1991-02-10   38344.0  False         Legal
# 990       Robin  Female 1987-07-24  100765.0   True            IT
# 993        Tina  Female 1997-05-15   56450.0   True   Engineering
# 994      George    Male 2013-06-21   98874.0   True     Marketing
# 995       Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN

# %%
emp.drop_duplicates(subset = ["Team"], keep = False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Salary, Mgmt, Team]
# Index: []

# %%
#Q. What does emp.drop_duplicates(subset = ["First Name"], keep = False) do?
emp.drop_duplicates(subset = ["First Name"], keep = False)
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 33        Jean  Female 1993-12-18  119082.0  False  Business Dev
# 190      Carol  Female 1996-03-19   57783.0  False       Finance
# 291      Tammy  Female 1984-11-11  132839.0   True            IT
# 495     Eugene    Male 1984-05-24   81077.0  False         Sales
# 688      Brian    Male 2007-04-07   93901.0   True         Legal
# 832      Keith    Male 2003-02-12  120672.0  False         Legal
# 887      David    Male 2009-12-05   92242.0  False         Legal

# %%
(
    emp["First Name"]
    .value_counts()
    .reset_index()
    .sort_values(['count'])
    .query('count == 1')
)
# Out:
#     First Name  count
# 192       Jean      1
# 193     Angela      1
# 194      Carol      1
# 195      Tammy      1
# 196     Eugene      1
# 197      Brian      1
# 198      Keith      1
# 199      David      1
# 191     Dennis      1

# %%
# Find a subset of all employees with a First Name of “Douglas” and a Gender of “Male”.
# Then check which “Douglas” is in the DataFrame emp.drop_duplicates(subset = ["Gender", "Team"])

emp.query("`First Name`=='Douglas' & Gender == 'Male'")
# Out:
#     First Name Gender Start Date    Salary   Mgmt         Team
# 0      Douglas   Male 1993-08-06       NaN   True    Marketing
# 217    Douglas   Male 1999-09-03   83341.0   True           IT
# 322    Douglas   Male 2002-01-08   41428.0  False      Product
# 835    Douglas   Male 2007-08-04  132175.0  False  Engineering

# %%
emp.query("`First Name`=='Douglas'")
# Out:
#     First Name Gender Start Date    Salary   Mgmt         Team
# 0      Douglas   Male 1993-08-06       NaN   True    Marketing
# 217    Douglas   Male 1999-09-03   83341.0   True           IT
# 322    Douglas   Male 2002-01-08   41428.0  False      Product
# 667    Douglas    NaN 2009-02-04  104496.0   True    Marketing
# 835    Douglas   Male 2007-08-04  132175.0  False  Engineering

# %%
emp.query("`First Name`=='Douglas' & Gender == 'Male'")
# Out:
#     First Name Gender Start Date    Salary   Mgmt         Team
# 0      Douglas   Male 1993-08-06       NaN   True    Marketing
# 217    Douglas   Male 1999-09-03   83341.0   True           IT
# 322    Douglas   Male 2002-01-08   41428.0  False      Product
# 835    Douglas   Male 2007-08-04  132175.0  False  Engineering

# %%
emp.drop_duplicates(subset = ["Gender", "Team"])
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# 10      Louise  Female 1980-08-12   63241.0   True           NaN
# 11       Julie  Female 1997-10-26  102508.0   True         Legal
# 12     Brandon    Male 1980-12-01  112807.0   True            HR
# 13        Gary    Male 2008-01-27  109831.0  False         Sales
# ...
