# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/299-code/blob/main/danl_299_script_2025_0917.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [1, 2, 3]
my_list.append(4)

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list = [1, 2, 3, 4, 2]
my_list.remove(2)
my_list
# Out:
# [1, 3, 4, 2]

# %%
my_list = [1, 2, 3, 4, 2]
my_list = [x for x in my_list if x != 2]
my_list
# Out:
# [1, 3, 4]

# %%
my_list = [1, 2, 3, 4]
del my_list[1]
my_list
# Out:
# [1, 3, 4]

# %%
my_list = [1, 2, 3, 4]
del my_list[1:3]
my_list
# Out:
# [1, 4]

# %%
my_dict = {'a': 1, 'b': 2}
my_dict.update({'c': 3})
my_dict
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
my_dict.update({'a': 10})
my_dict
# Out:
# {'a': 10, 'b': 2, 'c': 3}

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
my_dict = {k: v for k, v in my_dict.items() if v != 2}
my_dict
# Out:
# {'a': 1, 'c': 3}

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
del my_dict['b']
my_dict
# Out:
# {'a': 1, 'c': 3}

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2167009006.py in <cell line: 0>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# # try-except

# %%
my_list = [1,2,3,4,5]

my_list[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-175292889.py in <cell line: 0>()
#       1 my_list = [1,2,3,4,5]
#       2
# ----> 3 my_list[100]
#
# IndexError: list index out of range

# %%
my_dict = {'a':1, 'b':2, 'c':3}
my_dict['z']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-490056239.py in <cell line: 0>()
#       1 my_dict = {'a':1, 'b':2, 'c':3}
# ----> 2 my_dict['z']
#
# KeyError: 'z'

# %%
short_list = [1, 2, 3]
position = 5
short_list[position]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3463217681.py in <cell line: 0>()
#       1 short_list = [1, 2, 3]
#       2 position = 5
# ----> 3 short_list[position]
#
# IndexError: list index out of range

# %%
short_list = [1, 2, 3]
position = 5

try:
    short_list[position]
except:
    print('Need a position between 0 and', len(short_list)-1, ' but got', position)
# Out:
# Need a position between 0 and 2  but got 5

# %%
short_list = [1, 2, 3]
position = 2

try:
    val = short_list[position]
except:
    print('Need a position between 0 and', len(short_list)-1, ' but got',
    position)

val
# Out:
# 3

# %%
short_list = [1, 2, 3]
while True:
    value = input('Position [q to quit]? ')
    if value == 'q':
        break
    try:
        position = int(value)
        print(short_list[position])
    except IndexError as err:
        print('Bad index:', position, '-', err)
    except Exception as other:
        print('Something else broke:', other)
# Out:
# Position [q to quit]? 5
# Bad index: 5 - list index out of range
# Position [q to quit]? a
# Something else broke: invalid literal for int() with base 10: 'a'
# Position [q to quit]? q

# %%
import pandas as pd

# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv")
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
nba
# Out:
#                Name                 Team Position  Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG   9/26/96   1445697
# 1    Christian Wood      Detroit Pistons       PF   9/27/95   1645357
# 2     PJ Washington    Charlotte Hornets       PF   8/23/98   3831840
# 3      Derrick Rose      Detroit Pistons       PG   10/4/88   7317074
# 4     Marial Shayok   Philadelphia 76ers        G   7/26/95     79568
# ..              ...                  ...      ...       ...       ...
# 445   Austin Rivers      Houston Rockets       PG    8/1/92   2174310
# 446     Harry Giles     Sacramento Kings       PF   4/22/98   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960
# 449     Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000
#
# [450 rows x 5 columns]

# %%
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                  parse_dates = ["Birthday"])
nba
# Out:
# /tmp/ipython-input-2686974663.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# ...

# %%
from google.colab import drive, files
drive.mount('/content/drive')
files.upload()
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-5885ca46-a9b5-4890-af4a-b60cf8caccd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5885ca46-a9b5-4890-af4a-b60cf8caccd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
df = pd.read_csv("/content/aus_athletics_male.csv")
df
# Out:
#      rcc   wcc    hc    hg  ferr    bmi   ssf  pcBfat  lbm  height  weight  \
# 0   5.13   7.1  46.8  15.9    34  22.46  44.5    8.47   61   172.7    67.0
# 1   4.83   7.6  45.2  15.2    97  23.88  41.8    7.68   69   176.5    74.4
# 2   5.09   4.7  46.6  15.9    55  23.68  33.7    6.16   74   183.0    79.3
# 3   5.17   4.1  44.9  15.0    76  23.15  50.9    8.56   80   194.4    87.5
# 4   5.11   6.7  46.1  15.6    93  22.32  40.5    6.86   78   193.4    83.5
# ..   ...   ...   ...   ...   ...    ...   ...     ...  ...     ...     ...
# 78  4.63  14.3  44.8  15.0   133  25.43  49.5    8.97   79   185.3    87.3
# 79  5.11   7.0  47.7  15.8   214  24.54  70.0   11.63   80   191.5    90.0
# 80  5.34   6.2  49.8  17.2   143  27.79  75.7   13.49   82   184.6    94.7
# 81  4.86   8.9  46.9  15.8    65  23.58  57.7   10.25   68   179.9    76.3
# 82  4.90   7.6  45.6  16.0    90  27.56  67.2   11.79   82   183.9    93.2
#
#    sex       sport
# 0    m    swimming
# 1    m    swimming
# ...

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()  # Enabling an interactive DataFrame display
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
# !pip install itables
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.1 MB/s eta 0:00:00
# ...

# %%
# !pip install itables
from itables import init_notebook_mode, show
init_notebook_mode(all_interactive=False)
show(nba)
# Out:
# <script type="module">
#     import { set_or_remove_dark_class } from 'https://www.unpkg.com/dt_for_itables/dt_bundle.js';
#     set_or_remove_dark_class();
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_28964790_36c5_4132_90b3_cbd3b22117bf"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
# ...

# %%
boston = pd.read_csv("/content/boston.csv")
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# Below is to import the pandas library as pd
import pandas as pd

# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

# Below is to read nba.csv as nba DataFrame
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                  parse_dates = ["Birthday"])
# Out:
# /tmp/ipython-input-788510545.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    datetime64[ns]
#  4   Salary    450 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 17.7+ KB

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba.shape
# Out:
# (450, 5)

# %%
nba.shape[0]
# Out:
# 450

# %%
nba.shape[1]
# Out:
# 5

# %%
nba.dtypes
# Out:
# Name                object
# Team                object
# Position            object
# Birthday    datetime64[ns]
# Salary               int64
# dtype: object

# %%
type(nba.dtypes)
# Out:
# pandas.core.series.Series

# %%
nba.count()
# Out:
# Name        450
# Team        450
# Position    450
# Birthday    450
# Salary      450
# dtype: int64

# %%
nba.describe()
# Out:
#                   Birthday        Salary
# count                  450  4.500000e+02
# mean   1993-11-24 02:01:36  7.653584e+06
# min    1977-01-26 00:00:00  7.956800e+04
# 25%    1991-03-16 12:00:00  1.618520e+06
# 50%    1994-04-29 00:00:00  3.303074e+06
# 75%    1997-02-17 12:00:00  1.012957e+07
# max    2000-12-23 00:00:00  4.023176e+07
# std                    NaN  9.288810e+06

# %%
nba.describe(include='all')
# Out:
#                Name                Team Position             Birthday  \
# count           450                 450      450                  450
# unique          450                  30        9                  NaN
# top     Ricky Rubio  Philadelphia 76ers       PG                  NaN
# freq              1                  17       98                  NaN
# mean            NaN                 NaN      NaN  1993-11-24 02:01:36
# min             NaN                 NaN      NaN  1977-01-26 00:00:00
# 25%             NaN                 NaN      NaN  1991-03-16 12:00:00
# 50%             NaN                 NaN      NaN  1994-04-29 00:00:00
# 75%             NaN                 NaN      NaN  1997-02-17 12:00:00
# max             NaN                 NaN      NaN  2000-12-23 00:00:00
# std             NaN                 NaN      NaN                  NaN
#
#               Salary
# count   4.500000e+02
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
nba['Name']
# Out:
# 0        Shake Milton
# 1      Christian Wood
# 2       PJ Washington
# 3        Derrick Rose
# 4       Marial Shayok
#             ...
# 445     Austin Rivers
# 446       Harry Giles
# 447       Robin Lopez
# 448     Collin Sexton
# 449       Ricky Rubio
# Name: Name, Length: 450, dtype: object

# %%
nba_player_name_s = nba['Name']
nba_player_name_s
# Out:
# 0        Shake Milton
# 1      Christian Wood
# 2       PJ Washington
# 3        Derrick Rose
# 4       Marial Shayok
#             ...
# 445     Austin Rivers
# 446       Harry Giles
# 447       Robin Lopez
# 448     Collin Sexton
# 449       Ricky Rubio
# Name: Name, Length: 450, dtype: object

# %%
type(nba_player_name_s)
# Out:
# pandas.core.series.Series

# %%
nba_player_name_df = nba[ ['Name'] ]   # DataFrame
nba_player_name_df
# Out:
#                Name
# 0      Shake Milton
# 1    Christian Wood
# 2     PJ Washington
# 3      Derrick Rose
# 4     Marial Shayok
# ..              ...
# 445   Austin Rivers
# 446     Harry Giles
# 447     Robin Lopez
# 448   Collin Sexton
# 449     Ricky Rubio
#
# [450 rows x 1 columns]

# %%
type(nba_player_name_df)
# Out:
# pandas.core.frame.DataFrame

# %%
nba_player_name_team = nba[ ['Name', 'Team'] ]
nba_player_name_team
# Out:
#                Name                 Team
# 0      Shake Milton   Philadelphia 76ers
# 1    Christian Wood      Detroit Pistons
# 2     PJ Washington    Charlotte Hornets
# 3      Derrick Rose      Detroit Pistons
# 4     Marial Shayok   Philadelphia 76ers
# ..              ...                  ...
# 445   Austin Rivers      Houston Rockets
# 446     Harry Giles     Sacramento Kings
# 447     Robin Lopez      Milwaukee Bucks
# 448   Collin Sexton  Cleveland Cavaliers
# 449     Ricky Rubio         Phoenix Suns
#
# [450 rows x 2 columns]

# %%
nba_player_team_name = nba[ ['Team', 'Name'] ]
nba_player_team_name
# Out:
#                     Team            Name
# 0     Philadelphia 76ers    Shake Milton
# 1        Detroit Pistons  Christian Wood
# 2      Charlotte Hornets   PJ Washington
# 3        Detroit Pistons    Derrick Rose
# 4     Philadelphia 76ers   Marial Shayok
# ..                   ...             ...
# 445      Houston Rockets   Austin Rivers
# 446     Sacramento Kings     Harry Giles
# 447      Milwaukee Bucks     Robin Lopez
# 448  Cleveland Cavaliers   Collin Sexton
# 449         Phoenix Suns     Ricky Rubio
#
# [450 rows x 2 columns]

# %%
# To include only string variables
nba.select_dtypes(include = "object")
# Out:
#                Name                 Team Position
# 0      Shake Milton   Philadelphia 76ers       SG
# 1    Christian Wood      Detroit Pistons       PF
# 2     PJ Washington    Charlotte Hornets       PF
# 3      Derrick Rose      Detroit Pistons       PG
# 4     Marial Shayok   Philadelphia 76ers        G
# ..              ...                  ...      ...
# 445   Austin Rivers      Houston Rockets       PG
# 446     Harry Giles     Sacramento Kings       PF
# 447     Robin Lopez      Milwaukee Bucks        C
# 448   Collin Sexton  Cleveland Cavaliers       PG
# 449     Ricky Rubio         Phoenix Suns       PG
#
# [450 rows x 3 columns]

# %%
# To exclude string and integer variables
nba.select_dtypes(exclude = ["object", "int"])
# Out:
#       Birthday
# 0   1996-09-26
# 1   1995-09-27
# 2   1998-08-23
# 3   1988-10-04
# 4   1995-07-26
# ..         ...
# 445 1992-08-01
# 446 1998-04-22
# 447 1988-04-01
# 448 1999-01-04
# 449 1990-10-21
#
# [450 rows x 1 columns]

# %%
nba['Salary'].count()
# Out:
# np.int64(450)

# %%
type(nba['Salary'].count())
# Out:
# numpy.int64

# %%
nba[['Salary']].count()
# Out:
# Salary    450
# dtype: int64

# %%
type(nba[['Salary']].count())
# Out:
# pandas.core.series.Series

# %%
nba[['Salary', 'Birthday']].count()
# Out:
# Salary      450
# Birthday    450
# dtype: int64

# %%
nba['Team'].value_counts()
# Out:
# Team
# Philadelphia 76ers        17
# Brooklyn Nets             17
# Utah Jazz                 17
# Minnesota Timberwolves    17
# Charlotte Hornets         16
# Detroit Pistons           16
# New Orleans Pelicans      16
# New York Knicks           16
# Boston Celtics            16
# Chicago Bulls             16
# Toronto Raptors           16
# Los Angeles Lakers        16
# Atlanta Hawks             15
# Miami Heat                15
# Denver Nuggets            15
# Golden State Warriors     15
# Sacramento Kings          15
# Phoenix Suns              15
# Memphis Grizzlies         15
# Washington Wizards        14
# Milwaukee Bucks           14
# Los Angeles Clippers      14
# Houston Rockets           14
# San Antonio Spurs         14
# Portland Trail Blazers    14
# Cleveland Cavaliers       13
# Oklahoma City Thunder     13
# Orlando Magic             13
# Dallas Mavericks          13
# Indiana Pacers            13
# Name: count, dtype: int64

# %%
nba[ ['Team'] ].value_counts()
# Out:
# Team
# Brooklyn Nets             17
# Minnesota Timberwolves    17
# Philadelphia 76ers        17
# Utah Jazz                 17
# Chicago Bulls             16
# Boston Celtics            16
# New Orleans Pelicans      16
# Charlotte Hornets         16
# Toronto Raptors           16
# New York Knicks           16
# Los Angeles Lakers        16
# Detroit Pistons           16
# Golden State Warriors     15
# Atlanta Hawks             15
# Sacramento Kings          15
# Phoenix Suns              15
# Miami Heat                15
# Memphis Grizzlies         15
# Denver Nuggets            15
# Los Angeles Clippers      14
# Milwaukee Bucks           14
# Houston Rockets           14
# San Antonio Spurs         14
# Washington Wizards        14
# Portland Trail Blazers    14
# Cleveland Cavaliers       13
# Indiana Pacers            13
# Dallas Mavericks          13
# Orlando Magic             13
# Oklahoma City Thunder     13
# Name: count, dtype: int64

# %%
nba[ ['Team', 'Position'] ].value_counts()
# Out:
# Team                 Position
# Washington Wizards   PG          6
# Memphis Grizzlies    SF          6
# Chicago Bulls        PG          5
# Cleveland Cavaliers  PG          5
# San Antonio Spurs    PF          5
#                                 ..
# Sacramento Kings     SF          1
# Utah Jazz            G           1
#                      F           1
#                      SF          1
# Washington Wizards   SF          1
# Name: count, Length: 164, dtype: int64

# %%
type(nba[ ['Team', 'Position'] ].value_counts())
# Out:
# pandas.core.series.Series

# %%
nba[['Team']].nunique()
# Out:
# Team    30
# dtype: int64

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64
